# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import re
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
from requests import get
from bs4 import BeautifulSoup
from scipy import stats
import warnings
warnings.filterwarnings('ignore')


#import geopandas as gpd

from mpl_toolkits.basemap import Basemap
from IPython.display import set_matplotlib_formats
import os
import os.path
from geopy.geocoders import Nominatim

from matplotlib.collections import LineCollection


from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
import matplotlib.cm as cm
import matplotlib.colors as colors
from matplotlib.colors import Normalize

# %%
inspections = pd.read_csv('food-inspections.csv')

# %%
# Remove trailing backslash (left over from sodapy conversion of "License #" column)
inspections.rename(columns={"License #": "License"}, inplace=True)

# Drop rows with missing data
inspections.dropna(subset=["Inspection Date", "License", "Latitude", "Longitude"], inplace=True)

# Drop duplicates
inspections.drop_duplicates("Inspection ID", inplace=True)

# Drop "0" licenses
inspections = inspections[inspections.License != "0"]

# Only consider successful inspections
inspections = inspections[~inspections.Results.isin(["Out of Business", "Business Not Located", "No Entry"])]

# %%
# Convert latitude & longitude to floats
inspections.Latitude = inspections.Latitude.astype(float)
inspections.Longitude = inspections.Longitude.astype(float)

# %%
# Only consider canvass inspections (not complaints or re-inspections)
inspections = inspections[inspections['Inspection Type'] == "Canvass"]

# %%
# Only consider restaurants and grocery stores (subject to change)
inspections = inspections[inspections['Facility Type'].isin(["Restaurant", "Grocery Store"])]

# %%
inspections
# Out:
#         Inspection ID                  DBA Name                  AKA Name  \
# 1             2320342         YOLK TEST KITCHEN         YOLK TEST KITCHEN
# 5             2320261                CRAZY BIRD                CRAZY BIRD
# 7             2320298                   HAISOUS                 CA PHE DA
# 10            2320229  HIMALAYAN SHERPA KITCHEN  HIMALAYAN SHERPA KITCHEN
# 16            2320311    MAXWELL STREET EXPRESS    MAXWELL STREET EXPRESS
# ...               ...                       ...                       ...
# 194783          60244       ZARAGOZA RESTAURANT       ZARAGOZA RESTAURANT
# 194796          67743                EL MILAGRO                EL MILAGRO
# 194803         154219                SEDGWICK'S                SEDGWICK'S
# 194805          67759           FINLEY MAHONY'S           FINLEY MAHONY'S
# 194807         104236                TEMPO CAFE                TEMPO CAFE
#
#           License Facility Type             Risk                    Address  \
# 1       2589655.0    Restaurant    Risk 1 (High)      1767 N MILWAUKEE AVE
# 5       2616198.0    Restaurant    Risk 1 (High)          1160 W GRAND AVE
# 7       2464411.0    Restaurant    Risk 1 (High)  1800-1802 S CARPENTER ST
# 10      2670751.0    Restaurant    Risk 1 (High)       2701 W LAWRENCE AVE
# 16      1647725.0    Restaurant  Risk 2 (Medium)            1058 W 87TH ST
# ...           ...           ...              ...                        ...
# 194783  1904141.0    Restaurant    Risk 1 (High)         4852 S PULASKI RD
# 194796    43519.0    Restaurant    Risk 1 (High)       3050-3052 W 26TH ST
# 194803    30486.0    Restaurant    Risk 1 (High)        1935 N SEDGWICK ST
# 194805  1801271.0    Restaurant    Risk 1 (High)           3701 N BROADWAY
# 194807    80916.0    Restaurant    Risk 1 (High)           6 E CHESTNUT ST
#
#            City State      Zip  ...             Results  \
# 1       CHICAGO    IL  60647.0  ...  Pass w/ Conditions
# 5       CHICAGO    IL  60642.0  ...  Pass w/ Conditions
# 7       CHICAGO    IL  60608.0  ...                Pass
# 10      CHICAGO    IL  60625.0  ...  Pass w/ Conditions
# 16      CHICAGO    IL  60620.0  ...                Fail
# ...         ...   ...      ...  ...                 ...
# 194783  CHICAGO    IL  60632.0  ...                Pass
# 194796  CHICAGO    IL  60623.0  ...                Pass
# 194803  CHICAGO    IL  60614.0  ...                Pass
# 194805  CHICAGO    IL  60613.0  ...  Pass w/ Conditions
# 194807  CHICAGO    IL  60611.0  ...                Fail
#
#                                                Violations   Latitude  \
# 1       23. PROPER DATE MARKING AND DISPOSITION - Comm...  41.913588
# 5       16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED...  41.891193
# 7       47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  41.857963
# 10      5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  41.968442
# 16      5. PROCEDURES FOR RESPONDING TO VOMITING AND D...  41.736080
# ...                                                   ...        ...
# 194783  31. CLEAN MULTI-USE UTENSILS AND SINGLE SERVIC...  41.804468
# 194796  32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.844687
# 194803  30. FOOD IN ORIGINAL CONTAINER, PROPERLY LABEL...  41.917559
# 194805  3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATUR...  41.949250
# 194807  18. NO EVIDENCE OF RODENT OR INSECT OUTER OPEN...  41.898431
#
#         Longitude                                           Location  \
# 1      -87.682203  {'longitude': '41.9135877900482', 'latitude': ...
# 5      -87.657055  {'longitude': '41.891193484441246', 'latitude'...
# 7      -87.653358  {'longitude': '41.8579631274509', 'latitude': ...
# 10     -87.696304  {'longitude': '41.968442053562335', 'latitude'...
# 16     -87.650859  {'longitude': '41.7360797687383', 'latitude': ...
# ...           ...                                                ...
# 194783 -87.723633  {'longitude': '41.80446825925762', 'latitude':...
# 194796 -87.702188  {'longitude': '41.844686619118384', 'latitude'...
# 194803 -87.638645  {'longitude': '41.91755928707187', 'latitude':...
# 194805 -87.648260  {'longitude': '41.94924954780584', 'latitude':...
# 194807 -87.628009  {'longitude': '41.89843137207629', 'latitude':...
#
#         Historical Wards 2003-2015 Zip Codes  Community Areas  Census Tracts  \
# 1                              NaN       NaN              NaN            NaN
# 5                              NaN       NaN              NaN            NaN
# 7                              NaN       NaN              NaN            NaN
# 10                             NaN       NaN              NaN            NaN
# 16                             NaN       NaN              NaN            NaN
# ...                            ...       ...              ...            ...
# 194783                         NaN       NaN              NaN            NaN
# 194796                         NaN       NaN              NaN            NaN
# 194803                         NaN       NaN              NaN            NaN
# 194805                         NaN       NaN              NaN            NaN
# 194807                         NaN       NaN              NaN            NaN
#
#         Wards
# 1         NaN
# 5         NaN
# 7         NaN
# 10        NaN
# 16        NaN
# ...       ...
# 194783    NaN
# 194796    NaN
# 194803    NaN
# 194805    NaN
# 194807    NaN
#
# [64055 rows x 22 columns]

# %%
# %%capture
# !pip install folium

# %%
# Import necessary packages 
from folium import folium, plugins
from IPython.display import HTML

# %matplotlib inline

# %%
# Generate map
m = folium.Map([41.8600, -87.6298], zoom_start=10)

# Convert to (n, 2) nd-array format for heatmap
inspections_arr = inspections.sample(20000)[["Latitude", "Longitude"]].values

# Plot heatmap
m.add_child(plugins.HeatMap(inspections_arr.tolist(), radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # High Risk Facilities

# %%
high_risk = inspections.loc[data['Risk'] == ('Risk 1 (High)')]

# %%
# Generate map
m1 = folium.Map([41.8600, -87.6298], zoom_start=10)

# Convert to (n, 2) nd-array format for heatmap
inspections_arr = high_risk.sample(20000)[["Latitude", "Longitude"]].values

# Plot heatmap
m1.add_child(plugins.HeatMap(inspections_arr.tolist(), radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Medium Risk

# %%
medium_risk = inspections.loc[data['Risk'] == ('Risk 2 (Medium)')]
# Generate map
m2 = folium.Map([41.8600, -87.6298], zoom_start=10)

# Convert to (n, 2) nd-array format for heatmap
inspections_arr = medium_risk[["Latitude", "Longitude"]].values

# Plot heatmap
m2.add_child(plugins.HeatMap(inspections_arr.tolist(), radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Low Risk

# %%
low_risk = inspections.loc[data['Risk'] == ('Risk 3 (Low)')]
# Generate map
m2 = folium.Map([41.8600, -87.6298], zoom_start=10)

# Convert to (n, 2) nd-array format for heatmap
inspections_arr = low_risk[["Latitude", "Longitude"]].values

# Plot heatmap
m2.add_child(plugins.HeatMap(inspections_arr.tolist(), radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
